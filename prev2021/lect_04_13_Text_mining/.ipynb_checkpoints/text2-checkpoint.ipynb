# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import json

from sklearn.preprocessing import LabelEncoder


import seaborn as sn
#from pylab import rcParams      
#rcParams['figure.figsize'] = 8, 8
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

# %%
from sklearn.model_selection import StratifiedKFold, train_test_split, RandomizedSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# ###  Часть 1. Описание набора данных и признаков

# %%
f_name=['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence', 'negativereason', 'negativereason_confidence', 'airline','airline_sentiment_gold','name','negativereason_gold','retweet_count','text','tweet_coord','tweet_created','tweet_location','user_timezone']

# %%
memes = pd.read_csv('Tweets.csv') #, index_col="id")

# %%
memes.drop(columns="airline", axis=1)
# Out:
#                  tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0                tweet_id  airline_sentiment  airline_sentiment_confidence
# 1      570306133677760513            neutral                           1.0
# 2      570301130888122368           positive                        0.3486
# 3      570301083672813571            neutral                        0.6837
# 4      570301031407624196           negative                           1.0
# 5      570300817074462722           negative                           1.0
# 6      570300767074181121           negative                           1.0
# 7      570300616901320704           positive                        0.6745
# 8      570300248553349120            neutral                         0.634
# 9      570299953286942721           positive                        0.6559
# 10     570295459631263746           positive                           1.0
# 11     570294189143031808            neutral                        0.6769
# 12     570289724453216256           positive                           1.0
# 13     570289584061480960           positive                           1.0
# 14     570287408438120448           positive                        0.6451
# 15     570285904809598977           positive                           1.0
# 16     570282469121007616           negative                        0.6842
# 17     570277724385734656           positive                           1.0
# 18     570276917301137409           negative                           1.0
# 19     570270684619923457           positive                           1.0
# 20     570267956648792064           positive                           1.0
# 21     570265883513384960           negative                        0.6705
# 22     570264145116819457           positive                           1.0
# 23     570259420287868928           positive                           1.0
# 24     570258822297579520            neutral                           1.0
# 25     570256553502068736           negative                           1.0
# 26     570249102404923392           negative                           1.0
# 27     570239632807370753           negative                           1.0
# 28     570217831557677057            neutral                        0.6854
# 29     570207886493782019           negative                           1.0
# ...                   ...                ...                           ...
# 14611  569591765793165312           negative                           1.0
# 14612  569591730506371072            neutral                           1.0
# 14613  569591700416393216           negative                           1.0
# 14614  569591653121597440           negative                           1.0
# 14615  569591540944756737           negative                           1.0
# 14616  569591533617307648           negative                           1.0
# 14617  569591393540288512           negative                           1.0
# 14618  569591285150908416           positive                           1.0
# 14619  569591136534319105           negative                           1.0
# 14620  569590988395708416           positive                           1.0
# 14621  569590965880532993           negative                           1.0
# 14622  569590892085915649           negative                           1.0
# 14623  569590191758962688           negative                           1.0
# 14624  569590013278756865           positive                        0.6274
# 14625  569589959088173056           negative                           1.0
# 14626  569589643487928321           positive                           1.0
# 14627  569589460226183168           negative                           1.0
# 14628  569588816438169600           negative                           1.0
# 14629  569588651925098496           positive                           1.0
# 14630  569588591602458624           negative                           1.0
# 14631  569588473050611712           positive                           1.0
# 14632  569588464896876545           negative                           1.0
# 14633  569587813856841728            neutral            0.6759999999999999
# 14634  569587705937600512           negative                           1.0
# 14635  569587691626622976           negative                        0.6684
# 14636  569587686496825344           positive                        0.3487
# 14637  569587371693355008           negative                           1.0
# 14638  569587242672398336            neutral                           1.0
# 14639  569587188687634433           negative                           1.0
# 14640  569587140490866689            neutral                        0.6771
#
#                negativereason  negativereason_confidence  \
# 0              negativereason  negativereason_confidence
# 1                         NaN                        NaN
# 2                         NaN                        0.0
# 3                         NaN                        NaN
# 4                  Bad Flight                     0.7033
# 5                  Can't Tell                        1.0
# 6                  Can't Tell                     0.6842
# 7                         NaN                        0.0
# 8                         NaN                        NaN
# 9                         NaN                        NaN
# 10                        NaN                        NaN
# 11                        NaN                        0.0
# 12                        NaN                        NaN
# 13                        NaN                        NaN
# 14                        NaN                        NaN
# 15                        NaN                        NaN
# 16                Late Flight                     0.3684
# 17                        NaN                        NaN
# 18                 Bad Flight                        1.0
# 19                        NaN                        NaN
# 20                        NaN                        NaN
# 21                 Can't Tell                     0.3614
# 22                        NaN                        NaN
# 23                        NaN                        NaN
# 24                        NaN                        NaN
# 25     Customer Service Issue                     0.3557
# 26     Customer Service Issue                        1.0
# 27                 Can't Tell                     0.6614
# 28                        NaN                        NaN
# 29                 Bad Flight                        1.0
# ...                       ...                        ...
# 14611               longlines                     0.6788
# 14612                     NaN                        NaN
# 14613        Cancelled Flight                     0.6333
# 14614  Customer Service Issue                     0.7255
# 14615  Customer Service Issue                        1.0
# 14616        Cancelled Flight                        1.0
# 14617        Cancelled Flight                        1.0
# 14618                     NaN                        NaN
# 14619              Bad Flight                     0.6774
# 14620                     NaN                        NaN
# 14621  Customer Service Issue                        1.0
# 14622  Customer Service Issue                        1.0
# 14623             Late Flight                     0.3358
# 14624                     NaN                        0.0
# 14625              Can't Tell                        1.0
# 14626                     NaN                        NaN
# 14627             Late Flight                        1.0
# 14628        Cancelled Flight                        1.0
# 14629                     NaN                        NaN
# 14630  Customer Service Issue                        1.0
# 14631                     NaN                        NaN
# 14632              Bad Flight                        1.0
# 14633                     NaN                        0.0
# 14634        Cancelled Flight                        1.0
# 14635             Late Flight                     0.6684
# 14636                     NaN                        0.0
# 14637  Customer Service Issue                        1.0
# 14638                     NaN                        NaN
# 14639  Customer Service Issue                     0.6659
# 14640                     NaN                        0.0
#
#        airline_sentiment_gold             name  negativereason_gold  \
# 0      airline_sentiment_gold             name  negativereason_gold
# 1                         NaN          cairdin                  NaN
# 2                         NaN         jnardino                  NaN
# 3                         NaN       yvonnalynn                  NaN
# 4                         NaN         jnardino                  NaN
# 5                         NaN         jnardino                  NaN
# 6                         NaN         jnardino                  NaN
# 7                         NaN       cjmcginnis                  NaN
# 8                         NaN            pilot                  NaN
# 9                         NaN         dhepburn                  NaN
# 10                        NaN       YupitsTate                  NaN
# 11                        NaN  idk_but_youtube                  NaN
# 12                        NaN     HyperCamiLax                  NaN
# 13                        NaN     HyperCamiLax                  NaN
# 14                        NaN     mollanderson                  NaN
# 15                        NaN         sjespers                  NaN
# 16                        NaN  smartwatermelon                  NaN
# 17                        NaN    ItzBrianHunty                  NaN
# 18                        NaN    heatherovieda                  NaN
# 19                        NaN     thebrandiray                  NaN
# 20                        NaN        JNLpierce                  NaN
# 21                        NaN           MISSGJ                  NaN
# 22                        NaN           DT_Les                  NaN
# 23                        NaN       ElvinaBeck                  NaN
# 24                        NaN     rjlynch21086                  NaN
# 25                        NaN      ayeevickiee                  NaN
# 26                        NaN          Leora13                  NaN
# 27                        NaN    meredithjlynn                  NaN
# 28                        NaN       AdamSinger                  NaN
# 29                        NaN  blackjackpro911                  NaN
# ...                       ...              ...                  ...
# 14611                     NaN         Jess_JCW                  NaN
# 14612                     NaN      TrueChief77                  NaN
# 14613                     NaN    tcunningham10                  NaN
# 14614                     NaN     kiabeveridge                  NaN
# 14615                     NaN         GregPoos                  NaN
# 14616                     NaN       tim_sheehy                  NaN
# 14617                     NaN    TheJoshAbides                  NaN
# 14618                     NaN          iambmac                  NaN
# 14619                     NaN  A_for_AdNauseam                  NaN
# 14620                     NaN      howiemandel                  NaN
# 14621                     NaN         KCBobolz                  NaN
# 14622                     NaN      andyellwood                  NaN
# 14623                     NaN    Jill_Lynnette                  NaN
# 14624                     NaN   Flora_Lola_NYC                  NaN
# 14625                     NaN         yourlama                  NaN
# 14626                     NaN   DrCaseyJRudkin                  NaN
# 14627                     NaN       cataattack                  NaN
# 14628                     NaN   KristinaMeyer7                  NaN
# 14629                     NaN         jlhalldc                  NaN
# 14630                     NaN      jontgreen89                  NaN
# 14631                     NaN   Laurelinesblog                  NaN
# 14632                     NaN         MDDavis7                  NaN
# 14633                     NaN       Chad_SMFYM                  NaN
# 14634                     NaN  RussellsWriting                  NaN
# 14635                     NaN    GolfWithWoody                  NaN
# 14636                     NaN  KristenReenders                  NaN
# 14637                     NaN         itsropes                  NaN
# 14638                     NaN         sanyabun                  NaN
# 14639                     NaN       SraJackson                  NaN
# 14640                     NaN        daviddtwu                  NaN
#
#        retweet_count                                               text  \
# 0      retweet_count                                               text
# 1                  0                @VirginAmerica What @dhepburn said.
# 2                  0  @VirginAmerica plus you've added commercials t...
# 3                  0  @VirginAmerica I didn't today... Must mean I n...
# 4                  0  @VirginAmerica it's really aggressive to blast...
# 5                  0  @VirginAmerica and it's a really big bad thing...
# 6                  0  @VirginAmerica seriously would pay $30 a fligh...
# 7                  0  @VirginAmerica yes, nearly every time I fly VX...
# 8                  0  @VirginAmerica Really missed a prime opportuni...
# 9                  0    @virginamerica Well, I didn't…but NOW I DO! :-D
# 10                 0  @VirginAmerica it was amazing, and arrived an ...
# 11                 0  @VirginAmerica did you know that suicide is th...
# 12                 0  @VirginAmerica I &lt;3 pretty graphics. so muc...
# 13                 0  @VirginAmerica This is such a great deal! Alre...
# 14                 0  @VirginAmerica @virginmedia I'm flying your #f...
# 15                 0                             @VirginAmerica Thanks!
# 16                 0      @VirginAmerica SFO-PDX schedule is still MIA.
# 17                 0  @VirginAmerica So excited for my first cross c...
# 18                 0  @VirginAmerica  I flew from NYC to SFO last we...
# 19                 0                    I ❤️ flying @VirginAmerica. ☺️👍
# 20                 0  @VirginAmerica you know what would be amazingl...
# 21                 0  @VirginAmerica why are your first fares in May...
# 22                 0  @VirginAmerica I love this graphic. http://t.c...
# 23                 0  @VirginAmerica I love the hipster innovation. ...
# 24                 0  @VirginAmerica will you be making BOS&gt;LAS n...
# 25                 0  @VirginAmerica you guys messed up my seating.....
# 26                 0  @VirginAmerica status match program.  I applie...
# 27                 0  @VirginAmerica What happened 2 ur vegan food o...
# 28                 0  @VirginAmerica do you miss me? Don't worry we'...
# 29                 0  @VirginAmerica amazing to me that we can't get...
# ...              ...                                                ...
# 14611              0  @AmericanAir I understand the weather issue bu...
# 14612              0  @AmericanAir guarantee no retribution? If so, ...
# 14613              0  @AmericanAir a friend is having flight Cancell...
# 14614              0  @AmericanAir I used the "call back" feature wi...
# 14615              0  @AmericanAir I need to be at work tomorrow at ...
# 14616              0  @AmericanAir  ugh Dump us in dfw w/no luggage ...
# 14617              0  @AmericanAir Cancelled Flights my flight, does...
# 14618              0            @AmericanAir DMing you now! Big thanks.
# 14619              0  @AmericanAir 3078 is overweight so you pull 2 ...
# 14620              3  @AmericanAir I love your company and your staf...
# 14621              0  @AmericanAir I wait 2+ hrs for CS to call me b...
# 14622              0  @AmericanAir I've been on hold for 55 mins abo...
# 14623              0  I just need a place to sleep when I land witho...
# 14624              0  @AmericanAir Love the new planes for the JFK-L...
# 14625              0  @AmericanAir Call me Chairman, or call me Emer...
# 14626              0  @AmericanAir Flight 236 was great. Fantastic c...
# 14627              0  @AmericanAir Flight 953 NYC-Buenos Aires has b...
# 14628              0  @AmericanAir Flight Cancelled Flightled, can't...
# 14629              0  Thank you. “@AmericanAir: @jlhalldc Customer R...
# 14630              0  @AmericanAir How do I change my flight if the ...
# 14631              0                        @AmericanAir Thanks! He is.
# 14632              0  @AmericanAir thx for nothing on getting us out...
# 14633              0  “@AmericanAir: @TilleyMonsta George, that does...
# 14634              0  @AmericanAir my flight was Cancelled Flightled...
# 14635              0         @AmericanAir right on cue with the delays👌
# 14636              0  @AmericanAir thank you we got on a different f...
# 14637              0  @AmericanAir leaving over 20 minutes Late Flig...
# 14638              0  @AmericanAir Please bring American Airlines to...
# 14639              0  @AmericanAir you have my money, you change my ...
# 14640              0  @AmericanAir we have 8 ppl so we need 2 know h...
#
#                        tweet_coord              tweet_created  \
# 0                      tweet_coord              tweet_created
# 1                              NaN  2015-02-24 11:35:52 -0800
# 2                              NaN  2015-02-24 11:15:59 -0800
# 3                              NaN  2015-02-24 11:15:48 -0800
# 4                              NaN  2015-02-24 11:15:36 -0800
# 5                              NaN  2015-02-24 11:14:45 -0800
# 6                              NaN  2015-02-24 11:14:33 -0800
# 7                              NaN  2015-02-24 11:13:57 -0800
# 8                              NaN  2015-02-24 11:12:29 -0800
# 9                              NaN  2015-02-24 11:11:19 -0800
# 10                             NaN  2015-02-24 10:53:27 -0800
# 11                             NaN  2015-02-24 10:48:24 -0800
# 12                             NaN  2015-02-24 10:30:40 -0800
# 13                             NaN  2015-02-24 10:30:06 -0800
# 14                             NaN  2015-02-24 10:21:28 -0800
# 15                             NaN  2015-02-24 10:15:29 -0800
# 16                             NaN  2015-02-24 10:01:50 -0800
# 17                             NaN  2015-02-24 09:42:59 -0800
# 18                             NaN  2015-02-24 09:39:46 -0800
# 19                             NaN  2015-02-24 09:15:00 -0800
# 20                             NaN  2015-02-24 09:04:10 -0800
# 21                             NaN  2015-02-24 08:55:56 -0800
# 22     [40.74804263, -73.99295302]  2015-02-24 08:49:01 -0800
# 23                             NaN  2015-02-24 08:30:15 -0800
# 24                             NaN  2015-02-24 08:27:52 -0800
# 25                             NaN  2015-02-24 08:18:51 -0800
# 26                             NaN  2015-02-24 07:49:15 -0800
# 27                             NaN  2015-02-24 07:11:37 -0800
# 28                             NaN  2015-02-24 05:44:59 -0800
# 29       [42.361016, -71.02000488]  2015-02-24 05:05:28 -0800
# ...                            ...                        ...
# 14611                          NaN  2015-02-22 12:17:14 -0800
# 14612                          NaN  2015-02-22 12:17:05 -0800
# 14613  [40.46692522, -82.64567078]  2015-02-22 12:16:58 -0800
# 14614                          NaN  2015-02-22 12:16:47 -0800
# 14615                          NaN  2015-02-22 12:16:20 -0800
# 14616                          NaN  2015-02-22 12:16:18 -0800
# 14617                          NaN  2015-02-22 12:15:45 -0800
# 14618                          NaN  2015-02-22 12:15:19 -0800
# 14619                          NaN  2015-02-22 12:14:44 -0800
# 14620                          NaN  2015-02-22 12:14:08 -0800
# 14621                          NaN  2015-02-22 12:14:03 -0800
# 14622                          NaN  2015-02-22 12:13:45 -0800
# 14623                          NaN  2015-02-22 12:10:58 -0800
# 14624                          NaN  2015-02-22 12:10:16 -0800
# 14625   [32.9070889, -97.03785947]  2015-02-22 12:10:03 -0800
# 14626  [40.64946781, -73.76624703]  2015-02-22 12:08:48 -0800
# 14627                          NaN  2015-02-22 12:08:04 -0800
# 14628                          NaN  2015-02-22 12:05:30 -0800
# 14629                          NaN  2015-02-22 12:04:51 -0800
# 14630                          NaN  2015-02-22 12:04:37 -0800
# 14631                          NaN  2015-02-22 12:04:09 -0800
# 14632                          NaN  2015-02-22 12:04:07 -0800
# 14633                          NaN  2015-02-22 12:01:31 -0800
# 14634                          NaN  2015-02-22 12:01:06 -0800
# 14635                          NaN  2015-02-22 12:01:02 -0800
# 14636                          NaN  2015-02-22 12:01:01 -0800
# 14637                          NaN  2015-02-22 11:59:46 -0800
# 14638                          NaN  2015-02-22 11:59:15 -0800
# 14639                          NaN  2015-02-22 11:59:02 -0800
# 14640                          NaN  2015-02-22 11:58:51 -0800
#
#                       tweet_location                user_timezone
# 0                     tweet_location                user_timezone
# 1                                NaN   Eastern Time (US & Canada)
# 2                                NaN   Pacific Time (US & Canada)
# 3                          Lets Play   Central Time (US & Canada)
# 4                                NaN   Pacific Time (US & Canada)
# 5                                NaN   Pacific Time (US & Canada)
# 6                                NaN   Pacific Time (US & Canada)
# 7                   San Francisco CA   Pacific Time (US & Canada)
# 8                        Los Angeles   Pacific Time (US & Canada)
# 9                          San Diego   Pacific Time (US & Canada)
# 10                       Los Angeles   Eastern Time (US & Canada)
# 11                   1/1 loner squad   Eastern Time (US & Canada)
# 12                               NYC             America/New_York
# 13                               NYC             America/New_York
# 14                               NaN   Eastern Time (US & Canada)
# 15                 San Francisco, CA   Pacific Time (US & Canada)
# 16                     palo alto, ca   Pacific Time (US & Canada)
# 17                       west covina   Pacific Time (US & Canada)
# 18             this place called NYC   Eastern Time (US & Canada)
# 19      Somewhere celebrating life.        Atlantic Time (Canada)
# 20                  Boston | Waltham                        Quito
# 21                               NaN                          NaN
# 22                               NaN                          NaN
# 23                       Los Angeles   Pacific Time (US & Canada)
# 24                       Boston, MA    Eastern Time (US & Canada)
# 25                               714  Mountain Time (US & Canada)
# 26                               NaN                          NaN
# 27                               NaN                          NaN
# 28                 San Francisco, CA   Central Time (US & Canada)
# 29     San Mateo, CA & Las Vegas, NV                          NaN
# ...                              ...                          ...
# 14611                         London                       London
# 14612                   970 Colorado                          NaN
# 14613                   Central Ohio   Eastern Time (US & Canada)
# 14614                        Chicago  Mountain Time (US & Canada)
# 14615                            NaN                          NaN
# 14616                  Washington DC   Central Time (US & Canada)
# 14617                  New York City   Eastern Time (US & Canada)
# 14618              Columbus, OH, USA   Eastern Time (US & Canada)
# 14619                            NaN                          NaN
# 14620                            NaN   Pacific Time (US & Canada)
# 14621    Milwaukee County, Wisconsin   Central Time (US & Canada)
# 14622             New York, New York   Eastern Time (US & Canada)
# 14623                            NaN   Eastern Time (US & Canada)
# 14624                            NaN   Eastern Time (US & Canada)
# 14625                            NaN                          NaN
# 14626                     East Coast                          NaN
# 14627        Buenos Aires, Argentina                 Buenos Aires
# 14628                            NaN   Eastern Time (US & Canada)
# 14629                 Washington, DC   Eastern Time (US & Canada)
# 14630                       Waco, TX   Central Time (US & Canada)
# 14631                Chapel Hill, NC                          NaN
# 14632                             US   Eastern Time (US & Canada)
# 14633                            NaN   Central Time (US & Canada)
# 14634                    Los Angeles                      Arizona
# 14635                            NaN                        Quito
# 14636                            NaN                          NaN
# 14637                          Texas                          NaN
# 14638                  Nigeria,lagos                          NaN
# 14639                     New Jersey   Eastern Time (US & Canada)
# 14640                     dallas, TX                          NaN
#
# [14641 rows x 14 columns]

# %%
memes.shape
# Out:
# (9787, 15)

# %%
memes.head()
# Out:
#                                             tweet_id  airline_sentiment  \
# 0                                           tweet_id  airline_sentiment
# 1                                 570306133677760513            neutral
# 2                                 570301130888122368           positive
# 3                                 570301083672813571            neutral
# 4  570301031407624196,negative,1.0,Bad Flight,0.7...                NaN
#
#    airline_sentiment_confidence  negativereason  \
# 0  airline_sentiment_confidence  negativereason
# 1                           1.0             NaN
# 2                        0.3486             NaN
# 3                        0.6837             NaN
# 4     2015-02-24 11:15:36 -0800             NaN
#
#           negativereason_confidence         airline  airline_sentiment_gold  \
# 0         negativereason_confidence         airline  airline_sentiment_gold
# 1                               NaN  Virgin America                     NaN
# 2                               0.0  Virgin America                     NaN
# 3                               NaN  Virgin America                     NaN
# 4  Pacific Time (US & Canada)";;;;;             NaN                     NaN
#
#          name  negativereason_gold  retweet_count  \
# 0        name  negativereason_gold  retweet_count
# 1     cairdin                  NaN              0
# 2    jnardino                  NaN              0
# 3  yvonnalynn                  NaN              0
# 4         NaN                  NaN            NaN
#
#                                                 text  tweet_coord  \
# 0                                               text  tweet_coord
# 1                @VirginAmerica What @dhepburn said.          NaN
# 2  @VirginAmerica plus you've added commercials t...          NaN
# 3  @VirginAmerica I didn't today... Must mean I n...          NaN
# 4                                                NaN          NaN
#
#                   tweet_created  tweet_location  \
# 0                 tweet_created  tweet_location
# 1  Sun Jun 14 21:36:07 UTC 2009             NaN
# 2     2015-02-24 11:15:59 -0800             NaN
# 3     2015-02-24 11:15:48 -0800       Lets Play
# 4                           NaN             NaN
#
#                       user_timezone
# 0               user_timezone;;;;;;
# 1  Eastern Time (US & Canada);;;;;;
# 2  Pacific Time (US & Canada);;;;;;
# 3  Central Time (US & Canada);;;;;;
# 4                               NaN

# %%
memes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9787 entries, 0 to 9786
# Data columns (total 15 columns):
# tweet_id                        9787 non-null object
# airline_sentiment               4969 non-null object
# airline_sentiment_confidence    5021 non-null object
# negativereason                  2818 non-null object
# negativereason_confidence       3352 non-null object
# airline                         5011 non-null object
# airline_sentiment_gold          81 non-null object
# name                            4939 non-null object
# negativereason_gold             37 non-null object
# retweet_count                   4933 non-null object
# text                            4916 non-null object
# tweet_coord                     66 non-null object
# tweet_created                   4914 non-null object
# tweet_location                  2665 non-null object
# user_timezone                   4930 non-null object
# dtypes: object(15)
# memory usage: 1.1+ MB

# %%
memes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9787 entries, 0 to 9786
# Data columns (total 15 columns):
# tweet_id                        9787 non-null object
# airline_sentiment               4969 non-null object
# airline_sentiment_confidence    5021 non-null object
# negativereason                  2818 non-null object
# negativereason_confidence       3352 non-null object
# airline                         5011 non-null object
# airline_sentiment_gold          81 non-null object
# name                            4939 non-null object
# negativereason_gold             37 non-null object
# retweet_count                   4933 non-null object
# text                            4916 non-null object
# tweet_coord                     66 non-null object
# tweet_created                   4914 non-null object
# tweet_location                  2665 non-null object
# user_timezone                   4930 non-null object
# dtypes: object(15)
# memory usage: 1.1+ MB

# %%
memes.tail(3)
# Out:
#                                                tweet_id airline_sentiment  \
# 9784  569635391965405184,negative,1.0,Can't Tell,0.6...               NaN
# 9785                                 569634364780351488          positive
# 9786  569633357451153408,negative,1.0,Flight Booking...               NaN
#
#      airline_sentiment_confidence negativereason negativereason_confidence  \
# 9784                          NaN            NaN                       NaN
# 9785                          1.0            NaN                       NaN
# 9786                          NaN            NaN                       NaN
#
#          airline airline_sentiment_gold        name negativereason_gold  \
# 9784         NaN                    NaN         NaN                 NaN
# 9785  US Airways                    NaN  nanceebing                 NaN
# 9786         NaN                    NaN         NaN                 NaN
#
#      retweet_count                                               text  \
# 9784           NaN                                                NaN
# 9785             0  @USAirways please keep Emily at you gso airpor...
# 9786           NaN                                                NaN
#
#      tweet_coord              tweet_created        tweet_location  \
# 9784         NaN                        NaN                   NaN
# 9785         NaN  2015-02-22 15:06:30 -0800  south beach/ LA / NC
# 9786         NaN                        NaN                   NaN
#
#                          user_timezone
# 9784                               NaN
# 9785  Eastern Time (US & Canada);;;;;;
# 9786                               NaN

# %%
memes= memes.dropna(axis='index', how='any', subset=['tweet_created'])

# %%
memes = memes[pd.notnull(memes['tweet_created'])]

# %%
memes['tweet_created']=pd.to_datetime(memes['tweet_created'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-82a402dc418b> in <module>
# ----> 1 memes['tweet_created']=pd.to_datetime(memes['tweet_created'])
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     461             errors=errors,
#     462             require_iso8601=require_iso8601,
# --> 463             allow_object=True,
#     464         )
#     465
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1982             return values.view("i8"), tz_parsed
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#    1986     if tz_parsed is not None:
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1973             dayfirst=dayfirst,
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#    1977     except ValueError as e:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\Users\Public\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# C:\Users\Public\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', 'tweet_created')

# %% [markdown]
# # Время добавления
#
# Так как в нашем распоряжении есть чудесная переменная `added`, то можно поиграться с ней, преобразовав в понятный питону формат и повытаскивая из него час, день недели и месяца, месяц и год добавления

# %%
memes['Timestamp'] = pd.to_datetime(memes['tweet_created'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-5bbf29f40c3d> in <module>
# ----> 1 memes['Timestamp'] = pd.to_datetime(memes['tweet_created'])
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     776             result = arg.map(cache_array)
#     777         else:
# --> 778             values = convert_listlike(arg._values, True, format)
#     779             result = arg._constructor(values, index=arg.index, name=arg.name)
#     780     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     461             errors=errors,
#     462             require_iso8601=require_iso8601,
# --> 463             allow_object=True,
#     464         )
#     465
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1982             return values.view("i8"), tz_parsed
#    1983         except (ValueError, TypeError):
# -> 1984             raise e
#    1985
#    1986     if tz_parsed is not None:
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1973             dayfirst=dayfirst,
#    1974             yearfirst=yearfirst,
# -> 1975             require_iso8601=require_iso8601,
#    1976         )
#    1977     except ValueError as e:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\Users\Public\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1356         return parser(parserinfo).parse(timestr, **kwargs)
#    1357     else:
# -> 1358         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1359
#    1360
#
# C:\Users\Public\Anaconda3\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ValueError("Unknown string format:", timestr)
#     650
#     651         if len(res) == 0:
#
# ValueError: ('Unknown string format:', 'tweet_created')

# %%
memes['Year'] = memes.Timestamp.apply(lambda x: x.year)
memes['Month'] = memes.Timestamp.apply(lambda x: x.month)
memes['Day'] = memes.Timestamp.apply(lambda x: x.day)
memes['Hour'] = memes.Timestamp.apply(lambda x: x.hour)
memes['Weekday'] = memes.Timestamp.apply(lambda x: x.weekday())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-32c5e75a8701> in <module>
# ----> 1 memes['Year'] = memes.Timestamp.apply(lambda x: x.year)
#       2 memes['Month'] = memes.Timestamp.apply(lambda x: x.month)
#       3 memes['Day'] = memes.Timestamp.apply(lambda x: x.day)
#       4 memes['Hour'] = memes.Timestamp.apply(lambda x: x.hour)
#       5 memes['Weekday'] = memes.Timestamp.apply(lambda x: x.weekday())
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Timestamp'

# %%
memes.head()
# Out:
#              tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0            tweet_id  airline_sentiment  airline_sentiment_confidence
# 1  570306133677760513            neutral                           1.0
# 2  570301130888122368           positive                        0.3486
# 3  570301083672813571            neutral                        0.6837
# 5  570300817074462722           negative                           1.0
#
#    negativereason  negativereason_confidence         airline  \
# 0  negativereason  negativereason_confidence         airline
# 1             NaN                        NaN  Virgin America
# 2             NaN                        0.0  Virgin America
# 3             NaN                        NaN  Virgin America
# 5      Can't Tell                        1.0  Virgin America
#
#    airline_sentiment_gold        name  negativereason_gold  retweet_count  \
# 0  airline_sentiment_gold        name  negativereason_gold  retweet_count
# 1                     NaN     cairdin                  NaN              0
# 2                     NaN    jnardino                  NaN              0
# 3                     NaN  yvonnalynn                  NaN              0
# 5                     NaN    jnardino                  NaN              0
#
#                                                 text  tweet_coord  \
# 0                                               text  tweet_coord
# 1                @VirginAmerica What @dhepburn said.          NaN
# 2  @VirginAmerica plus you've added commercials t...          NaN
# 3  @VirginAmerica I didn't today... Must mean I n...          NaN
# 5  @VirginAmerica and it's a really big bad thing...          NaN
#
#                   tweet_created  tweet_location  \
# 0                 tweet_created  tweet_location
# 1  Sun Jun 14 21:36:07 UTC 2009             NaN
# 2     2015-02-24 11:15:59 -0800             NaN
# 3     2015-02-24 11:15:48 -0800       Lets Play
# 5     2015-02-24 11:14:45 -0800             NaN
#
#                       user_timezone
# 0               user_timezone;;;;;;
# 1  Eastern Time (US & Canada);;;;;;
# 2  Pacific Time (US & Canada);;;;;;
# 3  Central Time (US & Canada);;;;;;
# 5  Pacific Time (US & Canada);;;;;;

# %% [markdown]
# Также пригодится переменная, отвечающая за число дней, прошедших с момента добавления мема на сайт

# %%
memes['airline'] = (memes.Timestamp.max() - memes.Timestamp)/np.timedelta64(1, 'D')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-eb99c399cc44> in <module>
# ----> 1 memes['airline'] = (memes.Timestamp.max() - memes.Timestamp)/np.timedelta64(1, 'D')
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Timestamp'

# %% [markdown]
# А теперь для наших созданных переменных построим несколько гистограмм

# %%
index =0 
f, axarr = plt.subplots(2, 2, figsize=(15,10))
times = ['Month', 'Day', 'Hour', 'Weekday']
bins = [12, 31, 24, 7]
index = 0
for i in range(2):
    for j in range(2):
        axarr[i, j].hist(memes[times[index]], bins = bins[index])
        axarr[i, j].set_title('Histogram of {}'.format(times[index]))
        index += 1

f.subplots_adjust(hspace=0.2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-3eeb03f97a17> in <module>
#       6 for i in range(2):
#       7     for j in range(2):
# ----> 8         axarr[i, j].hist(memes[times[index]], bins = bins[index])
#       9         axarr[i, j].set_title('Histogram of {}'.format(times[index]))
#      10         index += 1
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Month'

# %% [markdown]
# Итак, что тут есть интересного:
# - День ничего необычного не принес, распределено достаточно равномерно
# - Гистограмма часа достаточно показательная - в ночной период активность значительно снижается, а затем растет, достигая пика примерно после окончания уроков у основной аудитории
# - По дням недели есть заметное снижения на выходных, интересно, почему бы это

# %%
memes.Year.value_counts().plot(kind='bar', figsize=(10, 5))
plt.title("Histogram of year")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-5873c2bfce34> in <module>
# ----> 1 memes.Year.value_counts().plot(kind='bar', figsize=(10, 5))
#       2 plt.title("Histogram of year")
#       3 plt.show()
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
memes.Year.value_counts(normalize=True).apply(lambda x: "{:.2f}%".format(x*100))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-c1c61b32491b> in <module>
# ----> 1 memes.Year.value_counts(normalize=True).apply(lambda x: "{:.2f}%".format(x*100))
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
plt.hist(memes.target)
#plt.title("Hist of log average views");
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-6238e6511cbf> in <module>
# ----> 1 plt.hist(memes.target)
#       2 #plt.title("Hist of log average views");
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %% [markdown]
# # ML

# %%
import nltk
from nltk.corpus import stopwords

# %%
stop = stopwords.words('english')
stemmer = nltk.stem.snowball.EnglishStemmer('english')

def data_Stemmer(text):
    return ' '.join([stemmer.stem(word) for word in text.split(' ') if word not in stop])

# %%
#memes["description"] = memes.tags.fillna("")+' '+\
                       memes.about.fillna("")+' '+\
                       memes.origin.fillna("")+' '+\
                       memes.other_text.fillna("")
# Out:
#   File "<ipython-input-32-b021cbd5acd0>", line 2
#     memes.about.fillna("")+' '+\
#     ^
# IndentationError: unexpected indent

# %%
memes.description = memes.description.apply(lambda x: x.lower().replace('unknown', ''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-2b8f18165efa> in <module>
# ----> 1 memes.description = memes.description.apply(lambda x: x.lower().replace('unknown', ''))
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %%
memes.description[4]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-4dd19e7bcd23> in <module>
# ----> 1 memes.description[4]
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %%
data_Stemmer(memes.description[4])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-76ad6fd26fd8> in <module>
# ----> 1 data_Stemmer(memes.description[4])
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %%
memes.description = memes.description.apply(lambda x: data_Stemmer(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-321e05646ce1> in <module>
# ----> 1 memes.description = memes.description.apply(lambda x: data_Stemmer(x))
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %%
X = memes.description
y = memes.target
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-10ad9800203f> in <module>
# ----> 1 X = memes.description
#       2 y = memes.target
#
# C:\Users\Public\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'description'

# %% [markdown]
# Для TF-IDF попробуем использовать биграммы, а чтобы словарь не раздувался до неадекватных размеров, ограничим минимальную частоты содержания слов в документах 0.1%. То есть будем выкидывать такие слова и биграммы, которые встречаются реже, чем в 0.1% документов.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf_vectorizer = TfidfVectorizer(stop_words=stop, ngram_range=(1, 2), min_df=0.001, norm=None)

# %%
Xtr, Xval, ytr, yval = train_test_split(X, y, test_size=0.30, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-ded8a030f2dd> in <module>
# ----> 1 Xtr, Xval, ytr, yval = train_test_split(X, y, test_size=0.30, random_state=42)
#
# NameError: name 'X' is not defined

# %%
Xtr_tfidf = tf_vectorizer.fit_transform(Xtr)
Xval_tfidf = tf_vectorizer.transform(Xval)
Xtr_tfidf.shape, Xval_tfidf.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-7ee4a2ee760a> in <module>
# ----> 1 Xtr_tfidf = tf_vectorizer.fit_transform(Xtr)
#       2 Xval_tfidf = tf_vectorizer.transform(Xval)
#       3 Xtr_tfidf.shape, Xval_tfidf.shape
#
# NameError: name 'Xtr' is not defined

# %% [markdown]
# Целевую переменную (среднее число просмотров в день), разделим на пять групп по квантилям, одновременно получая наивный baseline - если мы всем объектам примишем один класс, то итоговая точность составит 1/5 = 20%. Еще один плюс подхода - дисбаланса классов у нас точно не будет :)

# %%
#ytr_quantile = pd.qcut(ytr, q=5)

# %%
#ytr_quantile.value_counts()

# %% [markdown]
# Для будущих нужд запомним имеющиеся интервалы

# %%
#intervals = ytr_quantile.unique().categories.get_values()

# %%
#intervals

# %% [markdown]
# Так как на тестовой выборке мы аналогичное преобразование с квантильным разбиением выполнить не можем (группы не будут совпадать), запишем функцию для преобразования тестовых значений

# %%
"""
def quantile(y):
    for interval in intervals:
        if y<=interval.right:
            return interval
            break
    return interval
    """
# Out:
# '\ndef quantile(y):\n    for interval in intervals:\n        if y<=interval.right:\n            return interval\n            break\n    return interval\n    '

# %%
#yval_quantile = yval.apply(quantile)

# %%
#yval_quantile.value_counts()

# %% [markdown]
# Наконец, для обучения закодируем интервалы при помощи `LabelEncoder()`

# %%
#le = LabelEncoder()

# %%
#ytr_quantile = le.fit_transform(ytr_quantile)
#yval_quantile = le.transform(yval_quantile)

# %%
#ytr_quantile

# %%
#le.inverse_transform(ytr_quantile)

# %%
from sklearn.linear_model import SGDClassifier, LogisticRegressionCV

# %%
logit_sgd = SGDClassifier(
    loss='log', 
    shuffle=True, 
    n_iter_no_change=10, 
    max_iter=500, 
    penalty='l2', 
    random_state=42
)

# %%
logit_sgd.fit(Xtr_tfidf, ytr)

print(accuracy_score(logit_sgd.predict(Xtr_tfidf), ytr))
print(accuracy_score(logit_sgd.predict(Xval_tfidf), yval))

print(classification_report(logit_sgd.predict(Xval_tfidf), yval))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-080aab899e94> in <module>
# ----> 1 logit_sgd.fit(Xtr_tfidf, ytr)
#       2
#       3 print(accuracy_score(logit_sgd.predict(Xtr_tfidf), ytr))
#       4 print(accuracy_score(logit_sgd.predict(Xval_tfidf), yval))
#       5
#
# NameError: name 'Xtr_tfidf' is not defined

# %%
logit_cv = LogisticRegressionCV(Cs=10, n_jobs=-1)
logit_cv.fit(Xtr_tfidf, ytr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-fd470465fab1> in <module>
#       1 logit_cv = LogisticRegressionCV(Cs=10, n_jobs=-1)
# ----> 2 logit_cv.fit(Xtr_tfidf, ytr)
#
# NameError: name 'Xtr_tfidf' is not defined

# %%
print(accuracy_score(logit_cv.predict(Xtr_tfidf), ytr))
print(accuracy_score(logit_cv.predict(Xval_tfidf), yval))

print(classification_report(logit_cv.predict(Xval_tfidf), yval))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-f86a7eead968> in <module>
# ----> 1 print(accuracy_score(logit_cv.predict(Xtr_tfidf), ytr))
#       2 print(accuracy_score(logit_cv.predict(Xval_tfidf), yval))
#       3
#       4 print(classification_report(logit_cv.predict(Xval_tfidf), yval))
#
# NameError: name 'Xtr_tfidf' is not defined

# %%
def visualize_coefficients(coef, feature_names, title, plot_num, n_top_features=10):
    interesting_coefficients = np.argsort(coef)[-n_top_features:]
    
    plt.figure(figsize=(15, 15))
    plt.subplot(510+plot_num+1)
    colors = ["lightblue" for c in coef[interesting_coefficients]]
    plt.bar(np.arange(n_top_features), coef[interesting_coefficients], color=colors)
    feature_names = np.array(feature_names)
    plt.xticks(np.arange(1, 1 + n_top_features), 
               feature_names[interesting_coefficients], rotation=60, ha="right", fontsize=14);
    plt.title(title)

# %%
logit_sgd.coef_
# Out:
# array([[-1.04955284e+001, -1.04955284e+001, -1.04955284e+001, ...,
#         -2.80431784e-105, -2.70065562e-050, -2.70065562e-050],
#        [ 1.04955284e+001,  1.04955284e+001,  1.04955284e+001, ...,
#          4.04335843e-094, -7.46867645e-077, -7.46867645e-077],
#        [-4.12551720e+000, -4.12551720e+000, -9.90822438e+000, ...,
#         -3.71774931e-078,  3.43608172e-057,  3.43608172e-057]])

# %% [markdown]
# На графиках отображены по топ-25 слов, которые (по мнению логистической регресии), наиболее сильно увеличивают вероятность попадания в соответствующий класс популярности

# %%
#titles = ["Very sad", "Sad",  'Average','Happy', 'Very happy']
titles = ["Sad",  'Average','Happy']
#"Unpopular",
# 'Popular', 
for i in range(3):
    visualize_coefficients(logit_sgd.coef_[i,:], tf_vectorizer.get_feature_names(), 
                      title=titles[i], 
                           plot_num=i, n_top_features=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-30d164d8998c> in <module>
#       4 # 'Popular',
#       5 for i in range(3):
# ----> 6     visualize_coefficients(logit_sgd.coef_[i,:], tf_vectorizer.get_feature_names(),
#       7                       title=titles[i],
#       8                            plot_num=i, n_top_features=15)
#
# NameError: name 'visualize_coefficients' is not defined

# %%
i=3
visualize_coefficients(logit_sgd.coef_[i,:], tf_vectorizer.get_feature_names(), title=titles[i], plot_num=i, n_top_features=15)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-111-1f18ff2e486a> in <module>()
#       1 i=3
# ----> 2 visualize_coefficients(logit_sgd.coef_[i,:], tf_vectorizer.get_feature_names(), title=titles[i], plot_num=i, n_top_features=15)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
plt.hist(np.max(logit_cv.predict_proba(Xval_tfidf), axis=1));

# %%
predictions = logit_sgd.predict(Xval_tfidf)
certainty_mask = np.max(logit_sgd.predict_proba(Xval_tfidf), axis=1)>0.6

# %%
'''
meme_slice = memes.loc[Xval.index[certainty_mask]]
meme_slice['actual_popularity'] = le.inverse_transform(predictions[certainty_mask])
'''

# %%
'''
meme_slice[
    ['name', 'origin_year', 'date_added', 'views', 'description', 'average_views', 'actual_popularity']
].sort_values(by='views', ascending=False)'''

# %% [markdown]
# ### А теперь можно взглянуть на confusion matrix и посмотреть, где же косячат модели

# %%
def plot_confusion(predictions, yval, title):
    array = confusion_matrix(yval, predictions)
    df_cm = pd.DataFrame(array, index = [i for i in titles],
                      columns = [i for i in titles])
    plt.figure(figsize = (7,7))
    sn.heatmap(df_cm, annot=True, fmt='g', cbar=False)
    plt.title(title);

# %%
plot_confusion(logit_sgd.predict(Xval_tfidf), yval, "Logit regression")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-6466ebb99687> in <module>
# ----> 1 plot_confusion(logit_sgd.predict(Xval_tfidf), yval, "Logit regression")
#
# NameError: name 'logit_sgd' is not defined

# %%
plot_confusion(logit_cv.predict(Xval_tfidf), yval_quantile, "Logit regression")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-d4b03146843f> in <module>
# ----> 1 plot_confusion(logit_cv.predict(Xval_tfidf), yval_quantile, "Logit regression")
#
# NameError: name 'logit_cv' is not defined

# %%
y.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-bbbfd124eac3> in <module>
# ----> 1 y.unique()
#
# NameError: name 'y' is not defined
